# %% [markdown]
# # __Data Science and Business Analytics Intern at The Sparks Foundation__

# %% [markdown]
# ## <font color = red>Author </font>: <font color=green>  Ashit Kumar Rai</font>

# %% [markdown]
# ## <font color = red>Task 1 </font>: <font color=green>  Prediction using Supervised ML</font>

# %% [markdown]
# ### <font color = red>Problem Statement </font>: <font color=green>  create Linear Regression Model that predict the percentage of an student based on the no. of study hours.</font>

# %% [markdown]
# ### <font color = red>Goal </font>: <font color=green> The goal of this task is if we feed any new data(no. of study hours) in the model,<br> it would be able to predict the score of the student </font>

# %% [markdown]
# ### Step 1: Importing all libraries required in this notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# Reading data from given remote link
url = "https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv"
data = pd.read_csv(url)
print("Data imported successfully")

data.head(10)
# Out:
# Data imported successfully
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %% [markdown]
# plotting our data points on 2-D graph

# %%
data.plot(x='Hours', y='Scores', style='o')  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %% [markdown]
# **From the graph above, we can clearly see that there is a positive linear relation between the number of hours studied and percentage of score.**

# %% [markdown]
# ### step 2: **Preparing the data**
#
# dividing the data into "attributes" (inputs) and "labels" (outputs).

# %%
X = data.iloc[:, :-1].values  
Y = data.iloc[:, 1].values

# %% [markdown]
# ### Step 3: Splitting the data into training and test sets.

# %%
 X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size =0.2)

# %%
X_train.shape
# Out:
# (20, 1)

# %%
X_test.shape
# Out:
# (5, 1)

# %% [markdown]
# ### step 4: fitting linear regression model

# %%
regressor = LinearRegression()  
regressor.fit(X_train, Y_train) 

print("Training complete.")
# Out:
# Training complete.

# %% [markdown]
# ### step 5: Plotting the regression line

# %%
line = regressor.coef_*X+regressor.intercept_
plt.scatter(X, Y)
plt.plot(X, line);
plt.show()

# %% [markdown]
# ###  step 6 :Making Predictions

# %%
Y_predict = regressor.predict(X_test)
df = pd.DataFrame({"Actual": Y_test, "predicted": Y_predict})
df
# Out:
#    Actual  predicted
# 0      47  52.663548
# 1      76  70.769574
# 2      75  86.863819
# 3      20  16.451496
# 4      62  60.710670

# %% [markdown]
# ## What will be predicted score if a student studies for 9.25 hrs/ day?

# %%
predicted_score = regressor.predict([[9.25]])[0]
print(f"No. of Hours = {9.25}\n Predicted Score = {predicted_score}")
# Out:
# No. of Hours = 9.25
#  Predicted Score = 94.40799680031027

# %% [markdown]
# ### **Evaluating the model**

# %%
#by mean square error
print('Mean Absolute Error = ', 
      metrics.mean_absolute_error(Y_test, Y_predict))
# Out:
# Mean Absolute Error =  5.519125418141262
